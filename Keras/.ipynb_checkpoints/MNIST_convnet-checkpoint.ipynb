# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
from keras import layers
from keras import models
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 24, 24, 32)        832
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                36928
# ...

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11960785415776185337
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1472262963
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 13296780581532471936
# physical_device_desc: "device: 0, name: GeForce GTX 960, pci bus id: 0000:01:00.0, compute capability: 5.2"
# ]

# %%
from keras.datasets import mnist
from keras.utils import to_categorical

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
model.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size=64)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print(test_acc)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 6s 101us/step - loss: 0.1615 - acc: 0.9497
# Epoch 2/5
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.0448 - acc: 0.9859
# Epoch 3/5
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.0313 - acc: 0.9905: 3
# Epoch 4/5
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.0240 - acc: 0.9928
# Epoch 5/5
# ...
# 10000/10000 [==============================] - 1s 57us/step
# 0.992

# %%
test_labels.shape
# Out:
# (10000, 10)

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
n=8
m = 75
fig=plt.figure(figsize=(n, n))
k = 0
for i in range(1,n*n+1):
    while np.argmax(model.predict(test_images[k].reshape((-1,28,28,1)))) == np.argmax(test_labels[k]):
        k += 1
    fig.add_subplot(n, n, i)
    plt.imshow(test_images[k].reshape(28,28),cmap='gray')
    plt.text(0,10,np.argmax(model.predict(test_images[k].reshape((-1,28,28,1)))),fontsize=18,color='white')
    plt.text(20,10,np.argmax(test_labels[k]),fontsize=18,color='white')
    k+=1

plt.show()

# %%
import keras
keras.utils.plot_model(model, to_file='mnist.png', show_shapes=True)
