# %% [markdown]
# # Simple Reinforcement Learning in Tensorflow Part 1:
# ## The Multi-armed bandit
# This tutorial contains a simple example of how to build a policy-gradient based agent that can solve the multi-armed bandit problem. For more information, see this [Medium post](https://medium.com/@awjuliani/super-simple-reinforcement-learning-tutorial-part-1-fd544fab149).
#
# For more Reinforcement Learning algorithms, including DQN and Model-based learning in Tensorflow, see my Github repo, [DeepRL-Agents](https://github.com/awjuliani/DeepRL-Agents).

# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# ### The Bandits
# Here we define our bandits. For this example we are using a four-armed bandit. The pullBandit function generates a random number from a normal distribution with a mean of 0. The lower the bandit number, the more likely a positive reward will be returned. We want our agent to learn to always choose the bandit that will give that positive reward.

# %%
#List out our bandits. Currently bandit 4 (index#3) is set to most often provide a positive reward.
bandits = [0.2,0,-0.2,-0.3]
num_bandits = len(bandits)
def pullBandit(bandit):
    #Get a random number.
    result = np.random.randn(1)
    if result > bandit:
        #return a positive reward.
        return 1
    else:
        #return a negative reward.
        return -1

# %% [markdown]
# ### The Agent
# The code below established our simple neural agent. It consists of a set of values for each of the bandits. Each value is an estimate of the value of the return from choosing the bandit. We use a policy gradient method to update the agent by moving the value for the selected action toward the recieved reward.

# %%
tf.reset_default_graph()

#These two lines established the feed-forward part of the network. This does the actual choosing.
weights = tf.Variable(tf.ones([num_bandits]))
chosen_action = tf.argmax(weights,0)

#The next six lines establish the training proceedure. We feed the reward and chosen action into the network
#to compute the loss, and use it to update the network.
reward_holder = tf.placeholder(shape=[1],dtype=tf.float32)
action_holder = tf.placeholder(shape=[1],dtype=tf.int32)
responsible_weight = tf.slice(weights,action_holder,[1])
loss = -(tf.log(responsible_weight)*reward_holder)
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.0001)
update = optimizer.minimize(loss)

# %% [markdown]
# ### Training the Agent

# %% [markdown]
# We will train our agent by taking actions in our environment, and recieving rewards. Using the rewards and actions, we can know how to properly update our network in order to more often choose actions that will yield the highest rewards over time.

# %%
total_episodes = 1000 #Set total number of episodes to train agent on.
total_reward = np.zeros(num_bandits) #Set scoreboard for bandits to 0.
e = 0.1 #Set the chance of taking a random action.

init = tf.initialize_all_variables()

# Launch the tensorflow graph
with tf.Session() as sess:
    sess.run(init)
    i = 0
    while i < total_episodes:
        
        #Choose either a random action or one from our network.
        if np.random.rand(1) < e:
            action = np.random.randint(num_bandits)
        else:
            action = sess.run(chosen_action)
        
        reward = pullBandit(bandits[action]) #Get our reward from picking one of the bandits.
        
        #Update the network.
        _,resp,ww = sess.run([update,responsible_weight,weights], feed_dict={reward_holder:[reward],action_holder:[action]})
        #Update our running tally of scores.
        total_reward[action] += reward
        if i % 50 == 0:
            print ("Running reward for the " + str(num_bandits) + " bandits: " + str(total_reward))
        i+=1
print ("The agent thinks bandit " + str(np.argmax(ww)+1) + " is the most promising....")
if np.argmax(ww) == np.argmax(-np.array(bandits)):
    print ("...and it was right!")
else:
    print ("...and it was wrong!")
# Out:
# Running reward for the 4 bandits: [1. 0. 0. 0.]
# Running reward for the 4 bandits: [-1.  7.  1.  0.]
# Running reward for the 4 bandits: [0. 9. 0. 0.]
# Running reward for the 4 bandits: [1. 4. 0. 0.]
# Running reward for the 4 bandits: [ 0. -1.  6. -2.]
# Running reward for the 4 bandits: [ 0.  0. 17. -2.]
# Running reward for the 4 bandits: [ 0.  2. 23. -2.]
# Running reward for the 4 bandits: [ 0.  0. 30. -3.]
# Running reward for the 4 bandits: [ 2.  0. 38. -5.]
# Running reward for the 4 bandits: [ 2.  1. 43. -3.]
# Running reward for the 4 bandits: [ 1.  1. 39. -4.]
# Running reward for the 4 bandits: [ 2.  5. 37. -3.]
# Running reward for the 4 bandits: [ 2.  4. 64. -3.]
# Running reward for the 4 bandits: [ 0.  4. 76. -3.]
# Running reward for the 4 bandits: [ 0.  4. 92. -1.]
# Running reward for the 4 bandits: [ -1.   2. 103.  -3.]
# Running reward for the 4 bandits: [ -3.   2. 101.  -3.]
# Running reward for the 4 bandits: [ -2.   2. 111.  -2.]
# Running reward for the 4 bandits: [ -3.   4. 112.  -2.]
# Running reward for the 4 bandits: [ -3.   5. 134.  -1.]
# Running reward for the 4 bandits: [ -3.   4. 145.  -1.]
# Running reward for the 4 bandits: [ -2.   6. 148.   1.]
# Running reward for the 4 bandits: [ -1.   6. 151.   1.]
# Running reward for the 4 bandits: [ -1.   4. 158.   0.]
# Running reward for the 4 bandits: [  0.   5. 160.   0.]
# Running reward for the 4 bandits: [  1.   4. 160.   0.]
# Running reward for the 4 bandits: [  1.   4. 173.   1.]
# Running reward for the 4 bandits: [  1.   4. 177.   1.]
# Running reward for the 4 bandits: [  1.   4. 185.  -1.]
# Running reward for the 4 bandits: [  0.   5. 198.  -2.]
# Running reward for the 4 bandits: [  0.   5. 197.  -3.]
# Running reward for the 4 bandits: [ -2.   5. 208.   0.]
# Running reward for the 4 bandits: [ -2.   7. 205.   1.]
# Running reward for the 4 bandits: [  0.   7. 218.   0.]
# Running reward for the 4 bandits: [ -2.   5. 231.   1.]
# Running reward for the 4 bandits: [ -2.   5. 237.   3.]
# Running reward for the 4 bandits: [ -2.   6. 237.   6.]
# Running reward for the 4 bandits: [ -3.   6. 253.   5.]
# Running reward for the 4 bandits: [ -2.   7. 257.   5.]
# Running reward for the 4 bandits: [  0.   5. 263.   5.]
# Running reward for the 4 bandits: [  0.   4. 265.   4.]
# Running reward for the 4 bandits: [  0.   5. 288.   4.]
# Running reward for the 4 bandits: [ -1.   5. 291.   6.]
# Running reward for the 4 bandits: [ -2.   6. 297.   6.]
# Running reward for the 4 bandits: [ -1.   5. 295.   6.]
# Running reward for the 4 bandits: [ -1.   6. 296.   6.]
# Running reward for the 4 bandits: [ -5.   6. 310.   6.]
# Running reward for the 4 bandits: [ -5.   4. 306.   6.]
# Running reward for the 4 bandits: [ -5.   4. 296.   8.]
# Running reward for the 4 bandits: [ -6.   4. 305.   6.]
# Running reward for the 4 bandits: [ -6.   4. 305.   4.]
# Running reward for the 4 bandits: [ -6.   5. 301.   5.]
# Running reward for the 4 bandits: [ -5.   4. 332.   4.]
# Running reward for the 4 bandits: [ -7.   5. 332.   5.]
# Running reward for the 4 bandits: [ -9.   5. 348.   5.]
# Running reward for the 4 bandits: [ -8.   7. 357.   5.]
# Running reward for the 4 bandits: [ -9.   8. 358.   6.]
# Running reward for the 4 bandits: [ -9.   8. 375.   7.]
# Running reward for the 4 bandits: [ -9.   9. 378.   7.]
# Running reward for the 4 bandits: [ -8.  10. 390.   9.]
# Running reward for the 4 bandits: [ -5.  10. 392.  10.]
# Running reward for the 4 bandits: [ -5.  11. 412.   9.]
# Running reward for the 4 bandits: [ -5.  15. 420.   9.]
# Running reward for the 4 bandits: [ -5.  14. 429.   9.]
# Running reward for the 4 bandits: [ -6.  16. 448.   9.]
# Running reward for the 4 bandits: [ -5.  16. 446.   8.]
# Running reward for the 4 bandits: [ -4.  17. 457.   7.]
# Running reward for the 4 bandits: [ -4.  18. 466.   7.]
# Running reward for the 4 bandits: [ -4.  18. 469.   6.]
# Running reward for the 4 bandits: [ -4.  16. 482.   7.]
# Running reward for the 4 bandits: [ -6.  16. 484.   7.]
# Running reward for the 4 bandits: [ -6.  17. 492.   8.]
# Running reward for the 4 bandits: [ -5.  17. 511.   8.]
# Running reward for the 4 bandits: [ -4.  16. 518.   7.]
# Running reward for the 4 bandits: [ -4.  16. 527.   8.]
# Running reward for the 4 bandits: [ -3.  16. 534.   8.]
# Running reward for the 4 bandits: [ -3.  17. 542.   9.]
# Running reward for the 4 bandits: [ -1.  17. 555.   8.]
# Running reward for the 4 bandits: [ -1.  17. 563.  10.]
# Running reward for the 4 bandits: [ -2.  18. 582.   9.]
# Running reward for the 4 bandits: [ -4.  17. 592.  10.]
# Running reward for the 4 bandits: [ -3.  17. 600.   9.]
# Running reward for the 4 bandits: [ -3.  16. 601.   9.]
# Running reward for the 4 bandits: [ -4.  17. 614.  10.]
# Running reward for the 4 bandits: [ -7.  17. 620.  11.]
# Running reward for the 4 bandits: [ -5.  16. 636.  10.]
# Running reward for the 4 bandits: [ -5.  14. 650.  10.]
# Running reward for the 4 bandits: [ -5.  15. 647.  10.]
# Running reward for the 4 bandits: [ -6.  14. 660.   9.]
# Running reward for the 4 bandits: [ -7.  15. 678.   9.]
# Running reward for the 4 bandits: [-10.  17. 688.  10.]
# Running reward for the 4 bandits: [-10.  17. 696.  12.]
# Running reward for the 4 bandits: [ -9.  17. 707.  12.]
# Running reward for the 4 bandits: [-10.  17. 714.  12.]
# Running reward for the 4 bandits: [ -9.  19. 725.  12.]
# Running reward for the 4 bandits: [ -9.  18. 723.  13.]
# Running reward for the 4 bandits: [-10.  19. 731.  13.]
# Running reward for the 4 bandits: [-10.  19. 738.  14.]
# Running reward for the 4 bandits: [ -8.  17. 742.  14.]
# Running reward for the 4 bandits: [ -9.  16. 760.  14.]
# Running reward for the 4 bandits: [-10.  17. 773.  17.]
# Running reward for the 4 bandits: [-11.  20. 772.  18.]
# Running reward for the 4 bandits: [-12.  21. 771.  19.]
# Running reward for the 4 bandits: [-12.  21. 784.  20.]
# Running reward for the 4 bandits: [-13.  21. 796.  19.]
# Running reward for the 4 bandits: [-14.  21. 810.  18.]
# Running reward for the 4 bandits: [-13.  21. 809.  18.]
# Running reward for the 4 bandits: [-13.  21. 813.  18.]
# Running reward for the 4 bandits: [-13.  22. 814.  18.]
# Running reward for the 4 bandits: [-14.  22. 814.  19.]
# Running reward for the 4 bandits: [-15.  22. 825.  19.]
# Running reward for the 4 bandits: [-15.  22. 827.  19.]
# Running reward for the 4 bandits: [-15.  24. 835.  19.]
# Running reward for the 4 bandits: [-17.  23. 837.  18.]
# Running reward for the 4 bandits: [-16.  23. 837.  17.]
# Running reward for the 4 bandits: [-15.  23. 844.  17.]
# Running reward for the 4 bandits: [-15.  25. 845.  18.]
# Running reward for the 4 bandits: [-15.  26. 850.  20.]
# Running reward for the 4 bandits: [-14.  29. 863.  21.]
# Running reward for the 4 bandits: [-14.  30. 875.  24.]
# Running reward for the 4 bandits: [-15.  29. 895.  24.]
# Running reward for the 4 bandits: [-14.  31. 903.  23.]
# Running reward for the 4 bandits: [-14.  32. 906.  23.]
# Running reward for the 4 bandits: [-13.  31. 909.  24.]
# Running reward for the 4 bandits: [-12.  31. 917.  23.]
# Running reward for the 4 bandits: [-13.  32. 925.  23.]
# Running reward for the 4 bandits: [-13.  33. 939.  24.]
# Running reward for the 4 bandits: [-14.  33. 943.  25.]
# Running reward for the 4 bandits: [-13.  32. 948.  26.]
# Running reward for the 4 bandits: [-12.  32. 966.  27.]
# Running reward for the 4 bandits: [-14.  33. 989.  27.]
# Running reward for the 4 bandits: [-14.  34. 992.  27.]
# Running reward for the 4 bandits: [-14.  34. 990.  27.]
# Running reward for the 4 bandits: [-15.  34. 997.  29.]
# Running reward for the 4 bandits: [-17.  35. 990.  29.]
# Running reward for the 4 bandits: [-18.  35. 986.  28.]
# Running reward for the 4 bandits: [-20.  35. 990.  28.]
# Running reward for the 4 bandits: [-19.  34. 992.  28.]
# Running reward for the 4 bandits: [-19.  35. 999.  28.]
# Running reward for the 4 bandits: [-19.  35. 997.  28.]
# Running reward for the 4 bandits: [ -19.   35. 1008.   27.]
# Running reward for the 4 bandits: [ -19.   35. 1007.   28.]
# Running reward for the 4 bandits: [ -17.   38. 1021.   29.]
# Running reward for the 4 bandits: [ -17.   40. 1029.   29.]
# Running reward for the 4 bandits: [ -17.   41. 1031.   30.]
# Running reward for the 4 bandits: [ -14.   41. 1029.   29.]
# Running reward for the 4 bandits: [ -12.   42. 1033.   28.]
# Running reward for the 4 bandits: [ -12.   41. 1037.   29.]
# Running reward for the 4 bandits: [ -10.   40. 1032.   29.]
# Running reward for the 4 bandits: [ -12.   40. 1032.   31.]
# Running reward for the 4 bandits: [ -12.   39. 1038.   30.]
# Running reward for the 4 bandits: [ -13.   40. 1049.   29.]
# Running reward for the 4 bandits: [ -14.   40. 1053.   28.]
# Running reward for the 4 bandits: [ -17.   40. 1064.   28.]
# Running reward for the 4 bandits: [ -20.   39. 1083.   27.]
# Running reward for the 4 bandits: [ -18.   39. 1088.   28.]
# Running reward for the 4 bandits: [ -15.   38. 1083.   29.]
# Running reward for the 4 bandits: [ -16.   37. 1095.   29.]
# Running reward for the 4 bandits: [ -18.   35. 1099.   27.]
# Running reward for the 4 bandits: [ -18.   34. 1114.   27.]
# Running reward for the 4 bandits: [ -18.   31. 1122.   30.]
# Running reward for the 4 bandits: [ -18.   30. 1129.   28.]
# Running reward for the 4 bandits: [ -19.   30. 1129.   27.]
# Running reward for the 4 bandits: [ -20.   31. 1126.   26.]
# Running reward for the 4 bandits: [ -18.   32. 1133.   26.]
# Running reward for the 4 bandits: [ -16.   30. 1139.   26.]
# Running reward for the 4 bandits: [ -14.   32. 1146.   27.]
# Running reward for the 4 bandits: [ -15.   31. 1157.   28.]
# Running reward for the 4 bandits: [ -15.   31. 1158.   29.]
# Running reward for the 4 bandits: [ -17.   32. 1173.   29.]
# Running reward for the 4 bandits: [ -18.   32. 1195.   30.]
# Running reward for the 4 bandits: [ -18.   31. 1192.   30.]
# Running reward for the 4 bandits: [ -19.   30. 1188.   30.]
# Running reward for the 4 bandits: [ -19.   31. 1193.   30.]
# Running reward for the 4 bandits: [ -20.   32. 1197.   30.]
# Running reward for the 4 bandits: [ -20.   29. 1202.   30.]
# Running reward for the 4 bandits: [ -19.   29. 1204.   31.]
# Running reward for the 4 bandits: [ -20.   27. 1220.   30.]
# Running reward for the 4 bandits: [ -20.   25. 1226.   32.]
# Running reward for the 4 bandits: [ -20.   26. 1228.   33.]
# Running reward for the 4 bandits: [ -19.   24. 1235.   33.]
# Running reward for the 4 bandits: [ -20.   24. 1243.   34.]
# Running reward for the 4 bandits: [ -22.   26. 1253.   34.]
# Running reward for the 4 bandits: [ -23.   27. 1257.   34.]
# Running reward for the 4 bandits: [ -27.   28. 1268.   36.]
# Running reward for the 4 bandits: [ -28.   27. 1273.   37.]
# Running reward for the 4 bandits: [ -29.   27. 1298.   35.]
# Running reward for the 4 bandits: [ -28.   29. 1315.   35.]
# Running reward for the 4 bandits: [ -28.   28. 1329.   36.]
# Running reward for the 4 bandits: [ -28.   27. 1321.   39.]
# Running reward for the 4 bandits: [ -28.   25. 1322.   40.]
# Running reward for the 4 bandits: [ -30.   24. 1326.   39.]
# Running reward for the 4 bandits: [ -32.   24. 1341.   38.]
# Running reward for the 4 bandits: [ -32.   24. 1348.   39.]
# Running reward for the 4 bandits: [ -32.   25. 1358.   40.]
# Running reward for the 4 bandits: [ -31.   25. 1358.   41.]
# Running reward for the 4 bandits: [ -30.   27. 1368.   42.]
# Running reward for the 4 bandits: [ -30.   25. 1363.   41.]
# Running reward for the 4 bandits: [ -29.   25. 1370.   41.]
# Running reward for the 4 bandits: [ -27.   25. 1387.   42.]
# The agent thinks bandit 3 is the most promising....
# ...and it was wrong!
