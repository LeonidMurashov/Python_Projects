# %%
import numpy as np

# %%
a = np.array([1,2,3])

# %%
def f():
    pass

# %%
s = ['hi', 'priv']

# %%
s*10
# Out:
# ['hi',
#  'priv',
#  'hi',
#  'priv',
#  'hi',
#  'priv',
#  'hi',
#  'priv',
#  'hi',
#  'priv',
#  'hi',
#  'priv',
#  'hi',
#  'priv',
#  'hi',
#  'priv',
#  'hi',
#  'priv',
#  'hi',
#  'priv']

# %%
r = range(6)

# %%
print(*r)
print(*[1,2,4,])
# Out:
# 0 1 2 3 4 5
# 1 2 4

# %%
a = np.linspace(0, 8, 9)
print(a)
# Out:
# [0. 1. 2. 3. 4. 5. 6. 7. 8.]
